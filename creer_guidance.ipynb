# %% [markdown]
# <a href="https://colab.research.google.com/github/Ref-ka/career_guidance/blob/main/creer_guidance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('/content/data.csv')
data = data.loc[data['Salary'] <= 600000]
print(data)
# Out:
#                                     Name             City          Experience  \
# 0                          Web-Developer          Ташкент  От 1 года до 3 лет
# 1              Python junior разработчик  Санкт-Петербург           Нет опыта
# 2              Junior программист Python              NaN  От 1 года до 3 лет
# 3                     Junior-разработчик           Москва           Нет опыта
# 4          Junior Frontend - разработчик     Екатеринбург           Нет опыта
# ..                                   ...              ...                 ...
# 391               Golang Developer (Уфа)              Уфа       От 3 до 6 лет
# 392  Разработчик PHP/Разработчик Битрикс           Москва  От 1 года до 3 лет
# 393              Системный администратор           Москва  От 1 года до 3 лет
# 394             Разработчик Go (backend)           Москва  От 1 года до 3 лет
# 395  Middle / Senior Python/Go developer        Ульяновск       От 3 до 6 лет
#
#            Employment    Salary
# 0    Полная занятость   86450.0
# 1    Полная занятость   50000.0
# 2    Полная занятость   70000.0
# 3    Полная занятость   60000.0
# 4    Полная занятость   50000.0
# ..                ...       ...
# 391  Полная занятость  239750.0
# 392  Полная занятость  150000.0
# 393  Полная занятость  220000.0
# 394  Полная занятость  450000.0
# 395  Полная занятость  140000.0
#
# [388 rows x 5 columns]

# %%
dis = sns.displot(data, x='Salary')

# %%
sns.displot(data, y='Employment')

# %%
sns.catplot(data.fillna(0), y='Employment', x='Salary', kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 25.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 51.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 51.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 50.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
tmp = data.groupby(['Employment', 'Experience'])['Salary'].mean().reset_index()
tmp = tmp.pivot(index='Employment', columns='Experience', values='Salary').fillna(0)
sns.heatmap(tmp)
# Out:
# <Axes: xlabel='Experience', ylabel='Employment'>

# %%
data_moscow = data.loc[data['City'] == 'Москва']
data_ekb = data.loc[data['City'] == 'Екатеринбург']
data_spb = data.loc[data['City'] == 'Санкт-Петербург']
data_ufa = data.loc[data['City'] == 'Уфа']
city_data = pd.concat([data_ufa, data_ekb, data_spb, data_moscow])
print(data_spb)
# Out:
#                                                   Name             City  \
# 1                            Python junior разработчик  Санкт-Петербург
# 9                            Junior Python разработчик  Санкт-Петербург
# 12                                 Junior Developer ИИ  Санкт-Петербург
# 21      Trainee/Intern/Junior Python backend developer  Санкт-Петербург
# 25                                Junior SQL developer  Санкт-Петербург
# 44                             Программист Python (ИИ)  Санкт-Петербург
# 51   Программист / Backend-разработчик (Junior / Ju...  Санкт-Петербург
# 58                                Frontend-разработчик  Санкт-Петербург
# 64                         Python-разработчик (Junior)  Санкт-Петербург
# 65                          Программист Python(Django)  Санкт-Петербург
# 66                                      Тестировщик ПО  Санкт-Петербург
# 77                       Junior/Middle DevOps Engineer  Санкт-Петербург
# 85            Сетевой инженер по тестированию (Python)  Санкт-Петербург
# 86                                 Менеджер IT проекта  Санкт-Петербург
# 91                             Инженер по тестированию  Санкт-Петербург
# 100                                    Веб-разработчик  Санкт-Петербург
# 105       Backend Python - разработчик (Middle/Senior)  Санкт-Петербург
# 112                                   Python developer  Санкт-Петербург
# 123          Junior Python-разработчик в области AI/ML  Санкт-Петербург
# 137         Программист (Junior - младший разработчик)  Санкт-Петербург
# 154                      Junior/Middle DevOps Engineer  Санкт-Петербург
# 158                                Менеджер IT проекта  Санкт-Петербург
# 160               Разработчик ПО \ Инженер-программист  Санкт-Петербург
# 165           Инженер-программист (Embedded Developer)  Санкт-Петербург
# 181                         Инженер-программист АСУ ТП  Санкт-Петербург
# 184                         Инженер-программист АСУ ТП  Санкт-Петербург
# 196                                    Разработчик С++  Санкт-Петербург
# 201                   Unreal Engine Developer (Middle)  Санкт-Петербург
# 209                             Рекрутер/HR специалист  Санкт-Петербург
# 210                               Программист QT / С++  Санкт-Петербург
# 216                                Инженер-программист  Санкт-Петербург
# 226                                Инженер-программист  Санкт-Петербург
# 227                                Fullstack developer  Санкт-Петербург
# 229                               Программист QT / C++  Санкт-Петербург
# 234                                Инженер-тестировщик  Санкт-Петербург
# 242                    Инженер-программист разработчик  Санкт-Петербург
# 254  Инженер-программист Desktop приложения (Senior...  Санкт-Петербург
# 261                         Инженер-программист АСУ ТП  Санкт-Петербург
# 265                                    Программист С++  Санкт-Петербург
# 268                                        QA Engineer  Санкт-Петербург
# 275                     Junior Программист 1С (Стажер)  Санкт-Петербург
# 289                                Инженер-электронщик  Санкт-Петербург
# 292                        Junior/Middle C++ developer  Санкт-Петербург
# 319                               Junior SQL developer  Санкт-Петербург
# 327                      Junior/Middle DevOps Engineer  Санкт-Петербург
# 340  Frontend на Vue разработчик Интеллектуальной Т...  Санкт-Петербург
# 341                                   Java-программист  Санкт-Петербург
# 353  Senior JavaScript/TypeScript Developer (AdTech...  Санкт-Петербург
# 358                                        Программист  Санкт-Петербург
# 365                                Инженер-разработчик  Санкт-Петербург
# 372                                     Go-разработчик  Санкт-Петербург
# 374                                Backend-разработчик  Санкт-Петербург
# 390                                    PHP-программист  Санкт-Петербург
#
#              Experience           Employment    Salary
# 1             Нет опыта     Полная занятость   50000.0
# 9    От 1 года до 3 лет     Полная занятость   60000.0
# 12            Нет опыта     Полная занятость   80000.0
# 21            Нет опыта           Стажировка   35000.0
# 25            Нет опыта     Полная занятость   50000.0
# 44            Нет опыта     Полная занятость  100000.0
# 51   От 1 года до 3 лет     Полная занятость   75000.0
# 58        От 3 до 6 лет     Полная занятость  105000.0
# 64   От 1 года до 3 лет     Полная занятость   80000.0
# 65   От 1 года до 3 лет     Полная занятость  120000.0
# 66        От 3 до 6 лет     Полная занятость   75000.0
# 77   От 1 года до 3 лет     Полная занятость  140000.0
# 85   От 1 года до 3 лет     Полная занятость  150000.0
# 86   От 1 года до 3 лет     Полная занятость  190000.0
# 91   От 1 года до 3 лет     Полная занятость   90000.0
# 100       От 3 до 6 лет     Полная занятость  100000.0
# 105  От 1 года до 3 лет     Полная занятость  200000.0
# 112       От 3 до 6 лет     Полная занятость  140000.0
# 123  От 1 года до 3 лет     Полная занятость  100000.0
# 137           Нет опыта     Полная занятость   45000.0
# 154  От 1 года до 3 лет     Полная занятость  140000.0
# 158  От 1 года до 3 лет     Полная занятость  190000.0
# 160           Нет опыта     Полная занятость  120000.0
# 165           Нет опыта     Полная занятость   70000.0
# 181       От 3 до 6 лет     Полная занятость  200000.0
# 184       От 3 до 6 лет     Полная занятость  170000.0
# 196         Более 6 лет     Полная занятость  488506.0
# 201  От 1 года до 3 лет     Полная занятость  100000.0
# 209  От 1 года до 3 лет     Полная занятость   90000.0
# 210           Нет опыта     Полная занятость  140000.0
# 216  От 1 года до 3 лет     Полная занятость   72500.0
# 226           Нет опыта     Полная занятость   51500.0
# 227       От 3 до 6 лет     Полная занятость  175000.0
# 229           Нет опыта     Полная занятость   60000.0
# 234  От 1 года до 3 лет     Полная занятость   61000.0
# 242  От 1 года до 3 лет     Полная занятость  175000.0
# 254       От 3 до 6 лет     Полная занятость  150000.0
# 261       От 3 до 6 лет     Полная занятость  138000.0
# 265  От 1 года до 3 лет     Полная занятость  105000.0
# 268  От 1 года до 3 лет     Полная занятость   80000.0
# 275           Нет опыта     Полная занятость   40000.0
# 289  От 1 года до 3 лет  Частичная занятость   90000.0
# 292  От 1 года до 3 лет     Полная занятость   90000.0
# 319           Нет опыта     Полная занятость   50000.0
# 327  От 1 года до 3 лет     Полная занятость  140000.0
# 340       От 3 до 6 лет     Полная занятость  265000.0
# 341       От 3 до 6 лет     Полная занятость     140.0
# 353       От 3 до 6 лет     Полная занятость  386750.0
# 358       От 3 до 6 лет     Полная занятость  150000.0
# 365  От 1 года до 3 лет  Частичная занятость  200000.0
# 372  От 1 года до 3 лет     Полная занятость  180000.0
# 374       От 3 до 6 лет     Полная занятость  364000.0
# 390       От 3 до 6 лет     Полная занятость  115000.0

# %%
sns.displot(city_data, x='Salary', hue='City')

# %%
sns.catplot(city_data, x='Salary', hue='City')
